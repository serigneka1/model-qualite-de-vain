# %% [markdown]
# ## Librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Lire les données

# %%
ls
# Out:
# README.md              winequality-red.csv
# model_vin.ipynb        winequality-white.csv

# %%
rouge=pd.read_csv("winequality-red.csv", sep=";")
blanc=pd.read_csv("winequality-white.csv", sep=";")

# %%
rouge.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
blanc.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ### Les variables indépendantes (basées sur des tests physico-chimiques) sont:
#  - **fixed acidity:** acidité fixe
#  - **volatile:** activité volatile
#  - **acidity:** acidité
#  - **citric acidy:** acidité critique
#  - **residual sugar:** sucre résiduel
#  - **chlorides:** chlorure
#  - **free sulfur dioxide:**	anhydride sulfureux libre
#  - **total sulfur dioxide:** dioxyde de soufre total
#  - **density:**	densité
#  - **pH:** pH
#  - **sulphates:** sulfates
#  - **alcohol:**	alcool
# ### Le variable dépendanteou cible est:
#  - **quality:** qualité <br>
#  Elle correspont à la qualité du vain et est échelonnée de 0 à 10 correspondant respectivement à une très mauvaise qualité du vain et à une qualité excellente du vain

# %%
rouge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
blanc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
rouge["type_vain"]=1
blanc["type_vain"]=0

# %%
df=pd.concat([rouge, blanc])

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  type_vain             6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.6 KB

# %% [markdown]
# ### Analyse exploratoire

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type_vain               0
# dtype: int64

# %%
df["quality"].value_counts(normalize=True)
# Out:
# 6    0.436509
# 5    0.329075
# 7    0.166077
# 4    0.033246
# 8    0.029706
# 3    0.004618
# 9    0.000770
# Name: quality, dtype: float64

# %%
df.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# **Hypothèse:**
# - Vain de bonne qualité: score qualité >= 7
# - Vain de fabile qualité: score qualité < 7

# %%
df[df.quality>=7].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1277.000000        1277.00000  1277.000000     1277.000000
# mean        7.085709           0.28917     0.334628        4.827721
# std         1.342832           0.11696     0.110040        4.063824
# min         3.900000           0.08000     0.000000        0.800000
# 25%         6.300000           0.20000     0.280000        1.800000
# 50%         6.900000           0.27000     0.320000        2.900000
# 75%         7.400000           0.34000     0.380000        6.500000
# max        15.600000           0.91500     0.760000       19.250000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1277.000000          1277.000000           1277.000000  1277.000000
# mean      0.044576            31.055208            109.891151     0.993027
# std       0.021014            15.344154             47.126201     0.003007
# ...

# %%
df[df.quality<7].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5220.000000       5220.000000  5220.000000     5220.000000
# mean        7.247011          0.352019     0.314720        5.593812
# std         1.282968          0.172094     0.152466        4.901269
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.300000        3.000000
# 75%         7.700000          0.430000     0.400000        8.300000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5220.000000          5220.000000           5220.000000  5220.000000
# mean      0.058837            30.395690            117.176533     0.995105
# std       0.037145            18.288715             58.506354     0.002852
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# type_vain                  0.486740          0.653036    -0.187397
#
# ...

# %%
sns.heatmap(df.corr())
plt.show()

# %%
plt.figure(figsize=(10,10))
mask=np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(df.corr(), mask=mask,center=0, cmap='RdBu', linewidths=1, annot=True)
plt.title("coefficient de correction de Pearson entre variables")
plt.show()

# %% [markdown]
# ### Prétraitement
